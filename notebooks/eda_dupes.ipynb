# %%
# Change directory to level up to import functions
import os
os.chdir('..')

import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
premier_league_goals = pd.read_csv('data/premier_league_goals/combined_seasons/premier_league_goals.csv')
premier_league_assists = pd.read_csv('data/premier_league_assists/combined_seasons/premier_league_assists.csv')
championship_goals = pd.read_csv('data/championship_goals/combined_seasons/championship_goals.csv')
championship_assists = pd.read_csv('data/championship_assists/combined_seasons/championship_assists.csv')

# %%
premier_league_goals[premier_league_goals['Player']=='Andy Carroll'].sort_values('season_start')
# Out:
#             Player  Country              Team  Goals     Season  season_start
# 2540  Andy Carroll  England  Newcastle United      1  2007-2008          2007
# 2731  Andy Carroll  England  Newcastle United      3  2008-2009          2008
# 3264  Andy Carroll  England      Liverpool FC     20  2010-2011          2010
# 3693  Andy Carroll  England      Liverpool FC      7  2011-2012          2011
# 3975  Andy Carroll  England   West Ham United     12  2012-2013          2012
# 4396  Andy Carroll  England   West Ham United      4  2013-2014          2013
# 4690  Andy Carroll  England   West Ham United      6  2014-2015          2014
# 4952  Andy Carroll  England   West Ham United     11  2015-2016          2015
# 5316  Andy Carroll  England   West Ham United      8  2016-2017          2016
# 5749  Andy Carroll  England   West Ham United      3  2017-2018          2017
# 6413  Andy Carroll  England  Newcastle United      4  2019-2020          2019
# 6841  Andy Carroll  England  Newcastle United      1  2020-2021          2020
